# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import polars as pl

# %%
book_data = pd.read_csv('amazon_reviews_us_Books_v1_02.tsv', sep='\t',on_bad_lines='warn')
# Out:
# /var/folders/qg/cs1vp31s60j1j1c4k31w9tdw0000gn/T/ipykernel_14701/2027929391.py:1: ParserWarning: Skipping line 1680001: expected 15 fields, saw 22
#
#   book_data = pd.read_csv('amazon_reviews_us_Books_v1_02.tsv', sep='\t',on_bad_lines='warn')

# %%
book_data[book_data['customer_id'] == 53096589]
# Out:
#         marketplace  customer_id       review_id  product_id  product_parent  \
# 1614568          US     53096589  R2JYT0MI478PY3  0374523894       215877982
# 1615623          US     53096589   RVO5XJHT4O03T  0679721746       462852429
# 1615628          US     53096589   RJOZVVEQWZRZ3  0679766626       574131654
# 1615887          US     53096589  R2R8OZTR23Z8DU  0393320189       898276764
# 1630010          US     53096589  R3S50TSJN7OGND  0452266777       826207107
# 1642584          US     53096589    R6MAVX9REYOR  0252062876       294160429
# 1642968          US     53096589  R2GXJB8WF44Q2U  0679760008       645758434
# 1651259          US     53096589  R25OAEATSNICJJ  086316109X       199202211
# 1660154          US     53096589  R2LQH18EWGN3GU  0446527998       734163607
# 1671255          US     53096589    RAPDFGKU4M4D  0889104689       937861332
#
#                                              product_title product_category  \
# ...

# %%
survey_data = pd.read_csv("survey.csv")

# %%
survey_data
# Out:
#       Duration (in seconds)        RecordedDate         ResponseId  \
# 0                       332  9/21/2022 10:00:17  R_1ou69fj4DQGsVcp
# 1                       488  9/21/2022 10:02:24  R_24dboHVOzohx1kw
# 2                       309  9/21/2022 10:10:47  R_2UbJL30HRjK1sdD
# 3                       339  9/21/2022 10:13:03  R_UPXamGKtmf4RVIZ
# 4                       674  9/21/2022 11:36:51  R_2dYk5auG9Fv5Qve
# ...                     ...                 ...                ...
# 6320                    818  3/21/2023 21:59:02  R_2uKaOXO8LfgoFf3
# 6321                    172  3/21/2023 22:15:05  R_3lEpFGLEmx2Sv2J
# 6322                    579  3/21/2023 22:17:43  R_27Ee9Bw4FyMOZuZ
# 6323                   1244  3/21/2023 22:29:56  R_2ZZSS68rfn9BMtt
# 6324                    674  3/21/2023 23:03:09  R_273TMGuLM3jXisi
#
#      Q-prolific-mturk    q-demos-age Q-demos-hispanic  \
# 0                 NaN  35 - 44 years               No
# ...
