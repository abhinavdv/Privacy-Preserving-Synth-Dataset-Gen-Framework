# %%
import json
import pandas as pd

# Load the diseases list from a CSV file
diseases_df = pd.read_csv("disease_list.csv")
disease_keywords = diseases_df['Disease'].str.lower().tolist()  # Convert to lowercase for case-insensitive matching
disease_keyword_dict = set()
for dis in disease_keywords:
    if dis not in disease_keyword_dict:
        disease_keyword_dict.add(dis)
def extract_diseases_from_text(text, disease_keywords):
    """
    Extracts diseases directly from text by matching against a predefined list of diseases.
    """
    matched_diseases = []
    text = text.lower()
    # Check if any disease keyword exists as a substring in the text
    for disease in disease_keyword_dict:
        if disease in text:
            matched_diseases.append(disease)
    return list(set(matched_diseases))  # Remove duplicates

def process_batch(batch_data, disease_keywords):
    """
    Processes a batch of data and extracts disease information.
    """
    results = []
    for patient in batch_data:
        patient_text = patient.get("patient", "")
        title_text = patient.get("title", "")
        
        # Extract diseases from patient text and title
        diseases_from_patient = extract_diseases_from_text(patient_text, disease_keyword_dict)
        diseases_from_title = extract_diseases_from_text(title_text, disease_keyword_dict)
        diseases_from_both = list(set(diseases_from_patient) & set(diseases_from_title))
        
        # Determine the final 'disease' field
        if diseases_from_both:
            disease = diseases_from_both
        elif diseases_from_title:
            disease = diseases_from_title
        else:
            disease = diseases_from_patient
        
        # Append the patient data along with the extracted diseases
        results.append({
            "patient_id": patient["patient_id"],
            "patient_uid": patient["patient_uid"],
            "patient": patient_text,
            "title": title_text,
            "age": patient.get("age"),
            "gender": patient.get("gender"),
            "similar_patients": patient.get("similar_patients"),
            "diseases_from_patient": diseases_from_patient,
            "diseases_from_title": diseases_from_title,
            "diseases_from_both": diseases_from_both,
            "disease": disease  # Final disease field
        })
    return results

# Open and read the JSON data file in batches
input_file = "PMC-Patients.json"
output_file = "full_patients.json"
chunk_size = 1000

with open(input_file, "r") as file:
    data = json.load(file)

# Open the output file in append mode and start with an empty JSON array
with open(output_file, "w") as output:
    output.write("[\n")  # Start the JSON array

# Process data in batches
for i in range(0, len(data), chunk_size):
    batch_data = data[i:i + chunk_size]
    processed_results = process_batch(batch_data, disease_keywords)
    
    # Append results to the output file
    with open(output_file, "a") as output:
        json.dump(processed_results, output, indent=4)
        if i + chunk_size < len(data):
            output.write(",\n")  # Add a comma between JSON chunks
    
    print(f"Processed and appended batch {i // chunk_size + 1} to {output_file}")

# Close the JSON array
with open(output_file, "a") as output:
    output.write("\n]")
print(f"Final data saved to '{output_file}'")
# Out:
# Processed and appended batch 1 to full_patients.json
# Processed and appended batch 2 to full_patients.json
# Processed and appended batch 3 to full_patients.json
# Processed and appended batch 4 to full_patients.json
# Processed and appended batch 5 to full_patients.json
# Processed and appended batch 6 to full_patients.json
# Processed and appended batch 7 to full_patients.json
# Processed and appended batch 8 to full_patients.json
# Processed and appended batch 9 to full_patients.json
# Processed and appended batch 10 to full_patients.json
# Processed and appended batch 11 to full_patients.json
# Processed and appended batch 12 to full_patients.json
# Processed and appended batch 13 to full_patients.json
# Processed and appended batch 14 to full_patients.json
# Processed and appended batch 15 to full_patients.json
# Processed and appended batch 16 to full_patients.json
# Processed and appended batch 17 to full_patients.json
# Processed and appended batch 18 to full_patients.json
# Processed and appended batch 19 to full_patients.json
# Processed and appended batch 20 to full_patients.json
# Processed and appended batch 21 to full_patients.json
# Processed and appended batch 22 to full_patients.json
# Processed and appended batch 23 to full_patients.json
# Processed and appended batch 24 to full_patients.json
# Processed and appended batch 25 to full_patients.json
# Processed and appended batch 26 to full_patients.json
# Processed and appended batch 27 to full_patients.json
# Processed and appended batch 28 to full_patients.json
# Processed and appended batch 29 to full_patients.json
# Processed and appended batch 30 to full_patients.json
# Processed and appended batch 31 to full_patients.json
# Processed and appended batch 32 to full_patients.json
# Processed and appended batch 33 to full_patients.json
# Processed and appended batch 34 to full_patients.json
# Processed and appended batch 35 to full_patients.json
# Processed and appended batch 36 to full_patients.json
# Processed and appended batch 37 to full_patients.json
# Processed and appended batch 38 to full_patients.json
# Processed and appended batch 39 to full_patients.json
# Processed and appended batch 40 to full_patients.json
# Processed and appended batch 41 to full_patients.json
# Processed and appended batch 42 to full_patients.json
# Processed and appended batch 43 to full_patients.json
# Processed and appended batch 44 to full_patients.json
# Processed and appended batch 45 to full_patients.json
# Processed and appended batch 46 to full_patients.json
# Processed and appended batch 47 to full_patients.json
# Processed and appended batch 48 to full_patients.json
# Processed and appended batch 49 to full_patients.json
# Processed and appended batch 50 to full_patients.json
# Processed and appended batch 51 to full_patients.json
# Processed and appended batch 52 to full_patients.json
# Processed and appended batch 53 to full_patients.json
# Processed and appended batch 54 to full_patients.json
# Processed and appended batch 55 to full_patients.json
# Processed and appended batch 56 to full_patients.json
# Processed and appended batch 57 to full_patients.json
# Processed and appended batch 58 to full_patients.json
# Processed and appended batch 59 to full_patients.json
# Processed and appended batch 60 to full_patients.json
# Processed and appended batch 61 to full_patients.json
# Processed and appended batch 62 to full_patients.json
# Processed and appended batch 63 to full_patients.json
# Processed and appended batch 64 to full_patients.json
# Processed and appended batch 65 to full_patients.json
# Processed and appended batch 66 to full_patients.json
# Processed and appended batch 67 to full_patients.json
# Processed and appended batch 68 to full_patients.json
# Processed and appended batch 69 to full_patients.json
# Processed and appended batch 70 to full_patients.json
# Processed and appended batch 71 to full_patients.json
# Processed and appended batch 72 to full_patients.json
# Processed and appended batch 73 to full_patients.json
# Processed and appended batch 74 to full_patients.json
# Processed and appended batch 75 to full_patients.json
# Processed and appended batch 76 to full_patients.json
# Processed and appended batch 77 to full_patients.json
# Processed and appended batch 78 to full_patients.json
# Processed and appended batch 79 to full_patients.json
# Processed and appended batch 80 to full_patients.json
# Processed and appended batch 81 to full_patients.json
# Processed and appended batch 82 to full_patients.json
# Processed and appended batch 83 to full_patients.json
# Processed and appended batch 84 to full_patients.json
# Processed and appended batch 85 to full_patients.json
# Processed and appended batch 86 to full_patients.json
# Processed and appended batch 87 to full_patients.json
# Processed and appended batch 88 to full_patients.json
# Processed and appended batch 89 to full_patients.json
# Processed and appended batch 90 to full_patients.json
# Processed and appended batch 91 to full_patients.json
# Processed and appended batch 92 to full_patients.json
# Processed and appended batch 93 to full_patients.json
# Processed and appended batch 94 to full_patients.json
# Processed and appended batch 95 to full_patients.json
# Processed and appended batch 96 to full_patients.json
# Processed and appended batch 97 to full_patients.json
# Processed and appended batch 98 to full_patients.json
# Processed and appended batch 99 to full_patients.json
# Processed and appended batch 100 to full_patients.json
# Processed and appended batch 101 to full_patients.json
# Processed and appended batch 102 to full_patients.json
# Processed and appended batch 103 to full_patients.json
# Processed and appended batch 104 to full_patients.json
# Processed and appended batch 105 to full_patients.json
# Processed and appended batch 106 to full_patients.json
# Processed and appended batch 107 to full_patients.json
# Processed and appended batch 108 to full_patients.json
# Processed and appended batch 109 to full_patients.json
# Processed and appended batch 110 to full_patients.json
# Processed and appended batch 111 to full_patients.json
# Processed and appended batch 112 to full_patients.json
# Processed and appended batch 113 to full_patients.json
# Processed and appended batch 114 to full_patients.json
# Processed and appended batch 115 to full_patients.json
# Processed and appended batch 116 to full_patients.json
# Processed and appended batch 117 to full_patients.json
# Processed and appended batch 118 to full_patients.json
# Processed and appended batch 119 to full_patients.json
# Processed and appended batch 120 to full_patients.json
# Processed and appended batch 121 to full_patients.json
# Processed and appended batch 122 to full_patients.json
# Processed and appended batch 123 to full_patients.json
# Processed and appended batch 124 to full_patients.json
# Processed and appended batch 125 to full_patients.json
# Processed and appended batch 126 to full_patients.json
# Processed and appended batch 127 to full_patients.json
# Processed and appended batch 128 to full_patients.json
# Processed and appended batch 129 to full_patients.json
# Processed and appended batch 130 to full_patients.json
# Processed and appended batch 131 to full_patients.json
# Processed and appended batch 132 to full_patients.json
# Processed and appended batch 133 to full_patients.json
# Processed and appended batch 134 to full_patients.json
# Processed and appended batch 135 to full_patients.json
# Processed and appended batch 136 to full_patients.json
# Processed and appended batch 137 to full_patients.json
# Processed and appended batch 138 to full_patients.json
# Processed and appended batch 139 to full_patients.json
# Processed and appended batch 140 to full_patients.json
# Processed and appended batch 141 to full_patients.json
# Processed and appended batch 142 to full_patients.json
# Processed and appended batch 143 to full_patients.json
# Processed and appended batch 144 to full_patients.json
# Processed and appended batch 145 to full_patients.json
# Processed and appended batch 146 to full_patients.json
# Processed and appended batch 147 to full_patients.json
# Processed and appended batch 148 to full_patients.json
# Processed and appended batch 149 to full_patients.json
# Processed and appended batch 150 to full_patients.json
# Processed and appended batch 151 to full_patients.json
# Processed and appended batch 152 to full_patients.json
# Processed and appended batch 153 to full_patients.json
# Processed and appended batch 154 to full_patients.json
# Processed and appended batch 155 to full_patients.json
# Processed and appended batch 156 to full_patients.json
# Processed and appended batch 157 to full_patients.json
# Processed and appended batch 158 to full_patients.json
# Processed and appended batch 159 to full_patients.json
# Processed and appended batch 160 to full_patients.json
# Processed and appended batch 161 to full_patients.json
# Processed and appended batch 162 to full_patients.json
# Processed and appended batch 163 to full_patients.json
# Processed and appended batch 164 to full_patients.json
# Processed and appended batch 165 to full_patients.json
# Processed and appended batch 166 to full_patients.json
# Processed and appended batch 167 to full_patients.json
# Processed and appended batch 168 to full_patients.json
# Final data saved to 'full_patients.json'
